# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import os

# %% [markdown]
# # File's Path

# %%
notebook_path = os.getcwd()
db_files_path = "D:\Documentos\Turbinas\Test_22ITIBarge5MWSimulations"

# %%
#print(notebook_path)
#print(db_files_path)
# Out:
# C:\Users\Victor Ramos Fuentes\Documents\Turbinas
# D:\Documentos\Turbinas\Test_22ITIBarge5MWSimulations

# %%
fileJ1 = db_files_path + "\Test22Windrandompitchrandom.xlsx"
fileJ2 = db_files_path + "\Test22Windrandompitchrandom2.xlsx"

# %% [markdown]
# # Read File

# %%
df1 = pd.read_excel(fileJ1)
df2 = pd.read_excel(fileJ2)

# %% [markdown]
# # File's Analysis

# %% [markdown]
# ## File's dimensions

# %%
print("File J1 -> " + "Number of rows: " + str(df1.shape[0]) + " Number of columns: " + str(df1.shape[1]))
print("File J2 -> " + "Number of rows: " + str(df2.shape[0]) + " Number of columns: " + str(df2.shape[1]))
# Out:
# File J1 -> Number of rows: 24001 Number of columns: 97
# File J2 -> Number of rows: 4801 Number of columns: 97

# %% [markdown]
# ## File's columns

# %%
df1.columns
# Out:
# Index(['Time', 'Wind1VelX', 'Wind1VelY', 'Wind1VelZ', 'BldPitch1', 'BldPitch2',
#        'BldPitch3', 'Azimuth', 'RotSpeed', 'GenSpeed', 'NacYaw', 'OoPDefl1',
#        'IPDefl1', 'TwstDefl1', 'OoPDefl2', 'IPDefl2', 'TwstDefl2', 'OoPDefl3',
#        'IPDefl3', 'TwstDefl3', 'TwrClrnc1', 'TwrClrnc2', 'TwrClrnc3',
#        'NcIMUTAxs', 'NcIMUTAys', 'NcIMUTAzs', 'TTDspFA', 'TTDspSS',
#        'TTDspTwst', 'PtfmSurge', 'PtfmSway', 'PtfmHeave', 'PtfmRoll',
#        'PtfmPitch', 'PtfmYaw', 'PtfmTAxt', 'PtfmTAyt', 'PtfmTAzt', 'RootFxc1',
#        'RootFyc1', 'RootFzc1', 'RootMxc1', 'RootMyc1', 'RootMzc1', 'RootFxc2',
#        'RootFyc2', 'RootFzc2', 'RootMxc2', 'RootMyc2', 'RootMzc2', 'RootFxc3',
#        'RootFyc3', 'RootFzc3', 'RootMxc3', 'RootMyc3', 'RootMzc3', 'Spn1MLxb1',
#        'Spn1MLyb1', 'Spn1MLzb1', 'Spn1MLxb2', 'Spn1MLyb2', 'Spn1MLzb2',
#        'Spn1MLxb3', 'Spn1MLyb3', 'Spn1MLzb3', 'RotThrust', 'LSSGagFya',
#        'LSSGagFza', 'RotTorq', 'LSSGagMya', 'LSSGagMza', 'YawBrFxp',
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24001 entries, 0 to 24000
# Data columns (total 97 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Time       24001 non-null  float64
#  1   Wind1VelX  24001 non-null  float64
#  2   Wind1VelY  24001 non-null  float64
#  3   Wind1VelZ  24001 non-null  float64
#  4   BldPitch1  24001 non-null  float64
#  5   BldPitch2  24001 non-null  float64
#  6   BldPitch3  24001 non-null  float64
#  7   Azimuth    24001 non-null  float64
#  8   RotSpeed   24001 non-null  float64
#  9   GenSpeed   24001 non-null  float64
#  10  NacYaw     24001 non-null  float64
#  11  OoPDefl1   24001 non-null  float64
#  12  IPDefl1    24001 non-null  float64
#  13  TwstDefl1  24001 non-null  int64
#  14  OoPDefl2   24001 non-null  float64
#  15  IPDefl2    24001 non-null  float64
#  16  TwstDefl2  24001 non-null  int64
#  17  OoPDefl3   24001 non-null  float64
#  18  IPDefl3    24001 non-null  float64
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4801 entries, 0 to 4800
# Data columns (total 97 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Time       4801 non-null   float64
#  1   Wind1VelX  4801 non-null   float64
#  2   Wind1VelY  4801 non-null   float64
#  3   Wind1VelZ  4801 non-null   float64
#  4   BldPitch1  4801 non-null   float64
#  5   BldPitch2  4801 non-null   float64
#  6   BldPitch3  4801 non-null   float64
#  7   Azimuth    4801 non-null   float64
#  8   RotSpeed   4801 non-null   float64
#  9   GenSpeed   4801 non-null   float64
#  10  NacYaw     4801 non-null   float64
#  11  OoPDefl1   4801 non-null   float64
#  12  IPDefl1    4801 non-null   float64
#  13  TwstDefl1  4801 non-null   int64
#  14  OoPDefl2   4801 non-null   float64
#  15  IPDefl2    4801 non-null   float64
#  16  TwstDefl2  4801 non-null   int64
#  17  OoPDefl3   4801 non-null   float64
#  18  IPDefl3    4801 non-null   float64
# ...

# %%
df1.describe()
# Out:
#                Time     Wind1VelX     Wind1VelY     Wind1VelZ     BldPitch1  \
# count  24001.000000  24001.000000  24001.000000  24001.000000  24001.000000
# mean     150.000000     16.982408      0.020335      0.007306    973.020237
# std       86.607953      2.472728      1.983730      1.232373    142.859515
# min        0.000000     10.282837     -5.308509     -4.364331     -4.756762
# 25%       75.000000     15.159655     -1.370191     -0.825282    868.246277
# 50%      150.000000     17.066320     -0.100139      0.009865    977.942627
# 75%      225.000000     18.780481      1.333478      0.849123   1075.935303
# max      300.000000     25.013430      6.425784      4.628264   3229.204834
#
#           BldPitch2     BldPitch3       Azimuth      RotSpeed      GenSpeed  \
# count  24001.000000  24001.000000  24001.000000  24001.000000  24001.000000
# mean     973.020237    973.020237    140.733463      0.096728      9.415947
# ...

# %%
df2.describe()
# Out:
#               Time    Wind1VelX    Wind1VelY    Wind1VelZ    BldPitch1  \
# count  4801.000000  4801.000000  4801.000000  4801.000000  4801.000000
# mean     30.000000    12.935966     0.419425    -0.015828   741.176233
# std      17.325921     1.164820     1.096784     1.105517    70.869591
# min       0.000000     9.974622    -3.161915    -3.311421     0.000000
# 25%      15.000000    12.122225    -0.339005    -0.812086   694.741455
# 50%      30.000000    12.857203     0.544393    -0.028077   736.791565
# 75%      45.000000    13.705134     1.219170     0.756328   785.206970
# max      60.000000    16.446257     3.123255     3.395926  1997.871948
#
#          BldPitch2    BldPitch3      Azimuth     RotSpeed     GenSpeed  ...  \
# count  4801.000000  4801.000000  4801.000000  4801.000000  4801.000000  ...
# mean    741.176233   741.176233    65.667841     0.104657    10.096347  ...
# std      70.869591    70.869591   120.428578     0.830666    81.199721  ...
# ...
