# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import os

# %% [markdown]
# # File's Path

# %%
notebook_path = os.getcwd()
db_files_path = "D:\Documentos\Turbinas\Test_22ITIBarge5MWSimulations"

# %%
#print(notebook_path)
#print(db_files_path)
# Out:
# C:\Users\Victor Ramos Fuentes\Documents\Turbinas
# D:\Documentos\Turbinas\Test_22ITIBarge5MWSimulations

# %%
fileK3 = db_files_path + "\Test22Wind3pitchpulsetrend.xlsx"
fileK5 = db_files_path + "\Test22Wind5pitchpulsetrend.xlsx"
fileK8 = db_files_path + "\Test22Wind8pitchpulsetrend.xlsx"
fileK10 = db_files_path + "\Test22Wind10pitchpulsetrend.xlsx"
fileK114 = db_files_path + "\Test22Wind11-4pitchpulsetrend.xlsx"
fileK13 = db_files_path + "\Test22Wind13pitchpulsetrend.xlsx"
fileK17 = db_files_path + "\Test22Wind17pitchpulsetrend.xlsx"
fileK20 = db_files_path + "\Test22Wind20pitchpulsetrend.xlsx"
fileK21 = db_files_path + "\Test22Wind21pitchpulsetrend.xlsx"

# %% [markdown]
# # Read File

# %%
df1 = pd.read_excel(fileK3)
df2 = pd.read_excel(fileK5)
df3 = pd.read_excel(fileK8)
df4 = pd.read_excel(fileK10)
df5 = pd.read_excel(fileK114)
df6 = pd.read_excel(fileK13)
df7 = pd.read_excel(fileK17)
df8 = pd.read_excel(fileK20)
df9 = pd.read_excel(fileK21)

# %% [markdown]
# # File's Analysis

# %% [markdown]
# ## File's dimensions

# %%
print("File K3 -> " + "Number of rows: " + str(df1.shape[0]) + " Number of columns: " + str(df1.shape[1]))
print("File K5 -> " + "Number of rows: " + str(df2.shape[0]) + " Number of columns: " + str(df2.shape[1]))
print("File K8 -> " + "Number of rows: " + str(df3.shape[0]) + " Number of columns: " + str(df3.shape[1]))
print("File K10 -> " + "Number of rows: " + str(df4.shape[0]) + " Number of columns: " + str(df4.shape[1]))
print("File K11-4 -> " + "Number of rows: " + str(df5.shape[0]) + " Number of columns: " + str(df5.shape[1]))
print("File K13 -> " + "Number of rows: " + str(df6.shape[0]) + " Number of columns: " + str(df6.shape[1]))
print("File K17 -> " + "Number of rows: " + str(df7.shape[0]) + " Number of columns: " + str(df7.shape[1]))
print("File K20 -> " + "Number of rows: " + str(df8.shape[0]) + " Number of columns: " + str(df8.shape[1]))
print("File K21 -> " + "Number of rows: " + str(df9.shape[0]) + " Number of columns: " + str(df9.shape[1]))
# Out:
# File K3 -> Number of rows: 72001 Number of columns: 97
# File K5 -> Number of rows: 72001 Number of columns: 97
# File K8 -> Number of rows: 72001 Number of columns: 97
# File K10 -> Number of rows: 72001 Number of columns: 97
# File K11-4 -> Number of rows: 72001 Number of columns: 97
# File K13 -> Number of rows: 72001 Number of columns: 97
# File K17 -> Number of rows: 72001 Number of columns: 97
# File K20 -> Number of rows: 72001 Number of columns: 97
# File K21 -> Number of rows: 72001 Number of columns: 97

# %% [markdown]
# ## File's columns

# %%
df1.columns
# Out:
# Index(['Time', 'Wind1VelX', 'Wind1VelY', 'Wind1VelZ', 'BldPitch1', 'BldPitch2',
#        'BldPitch3', 'Azimuth', 'RotSpeed', 'GenSpeed', 'NacYaw', 'OoPDefl1',
#        'IPDefl1', 'TwstDefl1', 'OoPDefl2', 'IPDefl2', 'TwstDefl2', 'OoPDefl3',
#        'IPDefl3', 'TwstDefl3', 'TwrClrnc1', 'TwrClrnc2', 'TwrClrnc3',
#        'NcIMUTAxs', 'NcIMUTAys', 'NcIMUTAzs', 'TTDspFA', 'TTDspSS',
#        'TTDspTwst', 'PtfmSurge', 'PtfmSway', 'PtfmHeave', 'PtfmRoll',
#        'PtfmPitch', 'PtfmYaw', 'PtfmTAxt', 'PtfmTAyt', 'PtfmTAzt', 'RootFxc1',
#        'RootFyc1', 'RootFzc1', 'RootMxc1', 'RootMyc1', 'RootMzc1', 'RootFxc2',
#        'RootFyc2', 'RootFzc2', 'RootMxc2', 'RootMyc2', 'RootMzc2', 'RootFxc3',
#        'RootFyc3', 'RootFzc3', 'RootMxc3', 'RootMyc3', 'RootMzc3', 'Spn1MLxb1',
#        'Spn1MLyb1', 'Spn1MLzb1', 'Spn1MLxb2', 'Spn1MLyb2', 'Spn1MLzb2',
#        'Spn1MLxb3', 'Spn1MLyb3', 'Spn1MLzb3', 'RotThrust', 'LSSGagFya',
#        'LSSGagFza', 'RotTorq', 'LSSGagMya', 'LSSGagMza', 'YawBrFxp',
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72001 entries, 0 to 72000
# Data columns (total 97 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Time       72001 non-null  float64
#  1   Wind1VelX  72001 non-null  int64
#  2   Wind1VelY  72001 non-null  int64
#  3   Wind1VelZ  72001 non-null  int64
#  4   BldPitch1  72001 non-null  float64
#  5   BldPitch2  72001 non-null  float64
#  6   BldPitch3  72001 non-null  float64
#  7   Azimuth    72001 non-null  float64
#  8   RotSpeed   72001 non-null  float64
#  9   GenSpeed   72001 non-null  float64
#  10  NacYaw     72001 non-null  float64
#  11  OoPDefl1   72001 non-null  float64
#  12  IPDefl1    72001 non-null  float64
#  13  TwstDefl1  72001 non-null  int64
#  14  OoPDefl2   72001 non-null  float64
#  15  IPDefl2    72001 non-null  float64
#  16  TwstDefl2  72001 non-null  int64
#  17  OoPDefl3   72001 non-null  float64
#  18  IPDefl3    72001 non-null  float64
# ...

# %%
df1.describe()
# Out:
#                Time  Wind1VelX  Wind1VelY  Wind1VelZ     BldPitch1  \
# count  72001.000000    72001.0    72001.0    72001.0  7.200100e+04
# mean     450.000000        3.0        0.0        0.0  4.000058e+01
# std      259.813034        0.0        0.0        0.0  2.582174e+01
# min        0.000000        3.0        0.0        0.0 -1.704936e-11
# 25%      225.000000        3.0        0.0        0.0  2.000024e+01
# 50%      450.000000        3.0        0.0        0.0  3.999990e+01
# 75%      675.000000        3.0        0.0        0.0  6.000013e+01
# max      900.000000        3.0        0.0        0.0  1.000098e+02
#
#           BldPitch2     BldPitch3       Azimuth      RotSpeed      GenSpeed  \
# count  7.200100e+04  7.200100e+04  72001.000000  72001.000000  72001.000000
# mean   4.000058e+01  4.000058e+01    127.955605      0.143629     13.934565
# std    2.582174e+01  2.582174e+01    118.884900      1.076439    103.334057
# ...

# %%
df2.describe()
# Out:
#                Time  Wind1VelX  Wind1VelY  Wind1VelZ     BldPitch1  \
# count  72001.000000    72001.0    72001.0    72001.0  7.200100e+04
# mean     450.000000        5.0        0.0        0.0  4.000058e+01
# std      259.813034        0.0        0.0        0.0  2.582174e+01
# min        0.000000        5.0        0.0        0.0 -1.704936e-11
# 25%      225.000000        5.0        0.0        0.0  2.000024e+01
# 50%      450.000000        5.0        0.0        0.0  3.999990e+01
# 75%      675.000000        5.0        0.0        0.0  6.000013e+01
# max      900.000000        5.0        0.0        0.0  1.000098e+02
#
#           BldPitch2     BldPitch3       Azimuth      RotSpeed      GenSpeed  \
# count  7.200100e+04  7.200100e+04  72001.000000  72001.000000  72001.000000
# mean   4.000058e+01  4.000058e+01    215.036879      0.259958     25.219379
# std    2.582174e+01  2.582174e+01    100.071850      1.089522    104.661268
# ...

# %%
df3.describe()
# Out:
#                Time  Wind1VelX  Wind1VelY  Wind1VelZ     BldPitch1  \
# count  72001.000000    72001.0    72001.0    72001.0  7.200100e+04
# mean     450.000000        8.0        0.0        0.0  4.000058e+01
# std      259.813034        0.0        0.0        0.0  2.582174e+01
# min        0.000000        8.0        0.0        0.0 -1.704936e-11
# 25%      225.000000        8.0        0.0        0.0  2.000024e+01
# 50%      450.000000        8.0        0.0        0.0  3.999990e+01
# 75%      675.000000        8.0        0.0        0.0  6.000013e+01
# max      900.000000        8.0        0.0        0.0  1.000098e+02
#
#           BldPitch2     BldPitch3       Azimuth      RotSpeed      GenSpeed  \
# count  7.200100e+04  7.200100e+04  72001.000000  72001.000000  72001.000000
# mean   4.000058e+01  4.000058e+01    209.407634      0.661707     64.188137
# std    2.582174e+01  2.582174e+01    106.529736      1.802519    174.282934
# ...

# %%
df4.describe()
# Out:
#                Time  Wind1VelX  Wind1VelY  Wind1VelZ     BldPitch1  \
# count  72001.000000    72001.0    72001.0    72001.0  7.200100e+04
# mean     450.000000       10.0        0.0        0.0  4.000058e+01
# std      259.813034        0.0        0.0        0.0  2.582174e+01
# min        0.000000       10.0        0.0        0.0 -1.704936e-11
# 25%      225.000000       10.0        0.0        0.0  2.000024e+01
# 50%      450.000000       10.0        0.0        0.0  3.999990e+01
# 75%      675.000000       10.0        0.0        0.0  6.000013e+01
# max      900.000000       10.0        0.0        0.0  1.000098e+02
#
#           BldPitch2     BldPitch3       Azimuth      RotSpeed      GenSpeed  \
# count  7.200100e+04  7.200100e+04  72001.000000  72001.000000  72001.000000
# mean   4.000058e+01  4.000058e+01    183.783322      0.934655     90.662476
# std    2.582174e+01  2.582174e+01    118.953194      2.428485    235.182835
# ...

# %%
df5.describe()
# Out:
#                Time  Wind1VelX  Wind1VelY  Wind1VelZ     BldPitch1  \
# count  72001.000000    72001.0    72001.0    72001.0  7.200100e+04
# mean     450.000000       11.4        0.0        0.0  4.000058e+01
# std      259.813034        0.0        0.0        0.0  2.582174e+01
# min        0.000000       11.4        0.0        0.0 -1.704936e-11
# 25%      225.000000       11.4        0.0        0.0  2.000024e+01
# 50%      450.000000       11.4        0.0        0.0  3.999990e+01
# 75%      675.000000       11.4        0.0        0.0  6.000013e+01
# max      900.000000       11.4        0.0        0.0  1.000098e+02
#
#           BldPitch2     BldPitch3       Azimuth      RotSpeed      GenSpeed  \
# count  7.200100e+04  7.200100e+04  72001.000000  72001.000000  72001.000000
# mean   4.000058e+01  4.000058e+01    160.592376      1.295606    125.672403
# std    2.582174e+01  2.582174e+01     94.392888      2.990636    289.827922
# ...

# %%
df6.describe()
# Out:
#                Time  Wind1VelX  Wind1VelY  Wind1VelZ     BldPitch1  \
# count  72001.000000    72001.0    72001.0    72001.0  7.200100e+04
# mean     450.000000       13.0        0.0        0.0  4.000058e+01
# std      259.813034        0.0        0.0        0.0  2.582174e+01
# min        0.000000       13.0        0.0        0.0 -1.704936e-11
# 25%      225.000000       13.0        0.0        0.0  2.000024e+01
# 50%      450.000000       13.0        0.0        0.0  3.999990e+01
# 75%      675.000000       13.0        0.0        0.0  6.000013e+01
# max      900.000000       13.0        0.0        0.0  1.000098e+02
#
#           BldPitch2     BldPitch3       Azimuth      RotSpeed      GenSpeed  \
# count  7.200100e+04  7.200100e+04  72001.000000  72001.000000  72001.000000
# mean   4.000058e+01  4.000058e+01    176.161747      2.201140    213.507396
# std    2.582174e+01  2.582174e+01    116.487177      4.731050    458.786537
# ...

# %%
df7.describe()
# Out:
#                Time  Wind1VelX  Wind1VelY  Wind1VelZ     BldPitch1  \
# count  72001.000000    72001.0    72001.0    72001.0  7.200100e+04
# mean     450.000000       17.0        0.0        0.0  4.000058e+01
# std      259.813034        0.0        0.0        0.0  2.582174e+01
# min        0.000000       17.0        0.0        0.0 -1.704936e-11
# 25%      225.000000       17.0        0.0        0.0  2.000024e+01
# 50%      450.000000       17.0        0.0        0.0  3.999990e+01
# 75%      675.000000       17.0        0.0        0.0  6.000013e+01
# max      900.000000       17.0        0.0        0.0  1.000098e+02
#
#           BldPitch2     BldPitch3       Azimuth      RotSpeed      GenSpeed  \
# count  7.200100e+04  7.200100e+04  72001.000000  72001.000000  72001.000000
# mean   4.000058e+01  4.000058e+01    155.714503      5.952571    577.395135
# std    2.582174e+01  2.582174e+01    106.443025      9.353492    907.288032
# ...

# %%
df8.describe()
# Out:
#                Time  Wind1VelX  Wind1VelY  Wind1VelZ     BldPitch1  \
# count  72001.000000    72001.0    72001.0    72001.0  7.200100e+04
# mean     450.000000       20.0        0.0        0.0  4.000058e+01
# std      259.813034        0.0        0.0        0.0  2.582174e+01
# min        0.000000       20.0        0.0        0.0 -1.704936e-11
# 25%      225.000000       20.0        0.0        0.0  2.000024e+01
# 50%      450.000000       20.0        0.0        0.0  3.999990e+01
# 75%      675.000000       20.0        0.0        0.0  6.000013e+01
# max      900.000000       20.0        0.0        0.0  1.000098e+02
#
#           BldPitch2     BldPitch3       Azimuth      RotSpeed      GenSpeed  \
# count  7.200100e+04  7.200100e+04  72001.000000  72001.000000  72001.000000
# mean   4.000058e+01  4.000058e+01    194.337273      8.725792    846.396938
# std    2.582174e+01  2.582174e+01    107.847457     11.627455   1127.876105
# ...

# %%
df9.describe()
# Out:
#                Time  Wind1VelX  Wind1VelY  Wind1VelZ     BldPitch1  \
# count  72001.000000    72001.0    72001.0    72001.0  7.200100e+04
# mean     450.000000       21.0        0.0        0.0  4.000058e+01
# std      259.813034        0.0        0.0        0.0  2.582174e+01
# min        0.000000       21.0        0.0        0.0 -1.704936e-11
# 25%      225.000000       21.0        0.0        0.0  2.000024e+01
# 50%      450.000000       21.0        0.0        0.0  3.999990e+01
# 75%      675.000000       21.0        0.0        0.0  6.000013e+01
# max      900.000000       21.0        0.0        0.0  1.000098e+02
#
#           BldPitch2     BldPitch3       Azimuth      RotSpeed      GenSpeed  \
# count  7.200100e+04  7.200100e+04  72001.000000  72001.000000  72001.000000
# mean   4.000058e+01  4.000058e+01    181.949065      9.441195    915.790225
# std    2.582174e+01  2.582174e+01     98.403952     12.415750   1204.344011
# ...
