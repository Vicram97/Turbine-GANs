# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import os

# %% [markdown]
# # File's Path

# %%
notebook_path = os.getcwd()
db_files_path = "D:\Documentos\Turbinas\Test_22ITIBarge5MWSimulations"

# %%
#print(notebook_path)
#print(db_files_path)
# Out:
# C:\Users\Victor Ramos Fuentes\Documents\Turbinas
# D:\Documentos\Turbinas\Test_22ITIBarge5MWSimulations

# %%
fileN0 = db_files_path + "\Test22pulsetrendWindpitch0.xlsx"
fileN20 = db_files_path + "\Test22pulsetrendWindpitch20.xlsx"
fileN40 = db_files_path + "\Test22pulsetrendWindpitch40.xlsx"
fileN60 = db_files_path + "\Test22pulsetrendWindpitch60.xlsx"
fileN80 = db_files_path + "\Test22pulsetrendWindpitch80.xlsx"

# %% [markdown]
# # Read File

# %%
df1 = pd.read_excel(fileN0)
df2 = pd.read_excel(fileN20)
df3 = pd.read_excel(fileN40)
df4 = pd.read_excel(fileN60)
df5 = pd.read_excel(fileN80)

# %% [markdown]
# # File's Analysis

# %% [markdown]
# ## File's dimensions

# %%
print("File J1 -> " + "Number of rows: " + str(df1.shape[0]) + " Number of columns: " + str(df1.shape[1]))
print("File J2 -> " + "Number of rows: " + str(df2.shape[0]) + " Number of columns: " + str(df2.shape[1]))
print("File J3 -> " + "Number of rows: " + str(df3.shape[0]) + " Number of columns: " + str(df3.shape[1]))
print("File J4 -> " + "Number of rows: " + str(df4.shape[0]) + " Number of columns: " + str(df4.shape[1]))
print("File J5 -> " + "Number of rows: " + str(df5.shape[0]) + " Number of columns: " + str(df5.shape[1]))
# Out:
# File J1 -> Number of rows: 72001 Number of columns: 97
# File J2 -> Number of rows: 72001 Number of columns: 97
# File J3 -> Number of rows: 72001 Number of columns: 97
# File J4 -> Number of rows: 72001 Number of columns: 97
# File J5 -> Number of rows: 72001 Number of columns: 97

# %% [markdown]
# ## File's columns

# %%
df1.columns
# Out:
# Index(['Time', 'Wind1VelX', 'Wind1VelY', 'Wind1VelZ', 'BldPitch1', 'BldPitch2',
#        'BldPitch3', 'Azimuth', 'RotSpeed', 'GenSpeed', 'NacYaw', 'OoPDefl1',
#        'IPDefl1', 'TwstDefl1', 'OoPDefl2', 'IPDefl2', 'TwstDefl2', 'OoPDefl3',
#        'IPDefl3', 'TwstDefl3', 'TwrClrnc1', 'TwrClrnc2', 'TwrClrnc3',
#        'NcIMUTAxs', 'NcIMUTAys', 'NcIMUTAzs', 'TTDspFA', 'TTDspSS',
#        'TTDspTwst', 'PtfmSurge', 'PtfmSway', 'PtfmHeave', 'PtfmRoll',
#        'PtfmPitch', 'PtfmYaw', 'PtfmTAxt', 'PtfmTAyt', 'PtfmTAzt', 'RootFxc1',
#        'RootFyc1', 'RootFzc1', 'RootMxc1', 'RootMyc1', 'RootMzc1', 'RootFxc2',
#        'RootFyc2', 'RootFzc2', 'RootMxc2', 'RootMyc2', 'RootMzc2', 'RootFxc3',
#        'RootFyc3', 'RootFzc3', 'RootMxc3', 'RootMyc3', 'RootMzc3', 'Spn1MLxb1',
#        'Spn1MLyb1', 'Spn1MLzb1', 'Spn1MLxb2', 'Spn1MLyb2', 'Spn1MLzb2',
#        'Spn1MLxb3', 'Spn1MLyb3', 'Spn1MLzb3', 'RotThrust', 'LSSGagFya',
#        'LSSGagFza', 'RotTorq', 'LSSGagMya', 'LSSGagMza', 'YawBrFxp',
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72001 entries, 0 to 72000
# Data columns (total 97 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Time       72001 non-null  float64
#  1   Wind1VelX  72001 non-null  float64
#  2   Wind1VelY  72001 non-null  int64
#  3   Wind1VelZ  72001 non-null  int64
#  4   BldPitch1  72001 non-null  int64
#  5   BldPitch2  72001 non-null  int64
#  6   BldPitch3  72001 non-null  int64
#  7   Azimuth    72001 non-null  float64
#  8   RotSpeed   72001 non-null  float64
#  9   GenSpeed   72001 non-null  float64
#  10  NacYaw     72001 non-null  float64
#  11  OoPDefl1   72001 non-null  float64
#  12  IPDefl1    72001 non-null  float64
#  13  TwstDefl1  72001 non-null  int64
#  14  OoPDefl2   72001 non-null  float64
#  15  IPDefl2    72001 non-null  float64
#  16  TwstDefl2  72001 non-null  int64
#  17  OoPDefl3   72001 non-null  float64
#  18  IPDefl3    72001 non-null  float64
# ...

# %%
df1.describe()
# Out:
#                Time     Wind1VelX  Wind1VelY  Wind1VelZ  BldPitch1  BldPitch2  \
# count  72001.000000  72001.000000    72001.0    72001.0    72001.0    72001.0
# mean     450.000000      9.822364        0.0        0.0        0.0        0.0
# std      259.813034      5.950616        0.0        0.0        0.0        0.0
# min        0.000000      1.000000        0.0        0.0        0.0        0.0
# 25%      225.000000      5.000000        0.0        0.0        0.0        0.0
# 50%      450.000000     10.000000        0.0        0.0        0.0        0.0
# 75%      675.000000     13.000000        0.0        0.0        0.0        0.0
# max      900.000000     20.000000        0.0        0.0        0.0        0.0
#
#        BldPitch3       Azimuth      RotSpeed      GenSpeed  ...         GenTq  \
# count    72001.0  72001.000000  72001.000000  72001.000000  ...  72001.000000
# mean         0.0    153.256005     15.028449   1457.758233  ...     15.829548
# ...

# %%
df2.describe()
# Out:
#                Time     Wind1VelX  Wind1VelY  Wind1VelZ     BldPitch1  \
# count  72001.000